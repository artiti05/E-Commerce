# %%
import json

with open("Products.json", "r") as f:
    products = json.load(f)
products
# Out:
# {'Products': [{'product_id': 1,
#    'name': 'Game Controller',
#    'price': '10.99',
#    'qty': 100},
#   {'product_id': 2, 'name': 'Wireless Mouse', 'price': '20.50', 'qty': 50},
#   {'product_id': 3, 'name': 'Keyboard', 'price': '15.75', 'qty': 75}],
#  '101': {'name': 'Laptop', 'price': '1200.0', 'qty': 10},
#  '102': {'name': 'Wireless Mouse', 'price': '50.0', 'qty': 100},
#  '103': {'name': 'Mechanical Keyboard', 'price': '150.0', 'qty': 20}}
